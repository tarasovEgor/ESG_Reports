# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import copy
import re
from collections import defaultdict
from tqdm import tqdm
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from pymorphy2 import MorphAnalyzer

# %% [markdown]
# # Preprocess texts

# %%
df = pd.read_csv("news.csv.zip", index_col=0)
df.head()
# Out:
#                                                  url  \
# 0  https://www.finam.ru/publications/item/neftega...
# 1  https://bonds.finam.ru/news/item/roznichnye-in...
# 2  https://www.finam.ru/publications/item/v-tsena...
# 3  https://www.finam.ru/publications/item/gazprom...
# 4  https://www.finam.ru/publications/item/v-gazpr...
#
#                                                 text  company  \
# 0  Аналитики «Финама» подготовили стратегию по не...  gazprom
# 1  МОСКВА, 26 июл - РИА Новости/Прайм. Высокий ин...  gazprom
# 2  Цены на газ остаются высокими, хотя плавучие х...  gazprom
# 3  «Газпром» в ходе аукциона выиграл крупные газо...  gazprom
# 4  Оценивая перспективы инвестиции в акции «Газпр...  gazprom
#
#                                        cleaned_texts
# 0  аналитик финама подготовить стратегия нефтегаз...
# 1  москва июл риа новости/прайм высокий интерес в...
# 2  цена газ оставаться высокий хотя плавучий хран...
# 3  газпром ход аукцион выиграть крупный газовый у...
# 4  оценивать перспектива инвестиция акция газпром...

# %%
RE_RUSSIAN_TEXT = re.compile("[а-яА-Я]+")
EXCLUDE_PATTERNS = re.compile("[A-Za-z0-9!#$%&'()*+,./:;<=>?@[\]^_`{|}~—\"\-]+")
RE_DERIVED = re.compile("\w+( -|- |-|! - )\w+")

stopwords_ru = stopwords.words("russian")
morph = MorphAnalyzer()

# %%
cleaned_text = []
for _, row in tqdm(df.iterrows(), total=df.shape[0]):
    report_page = RE_DERIVED.sub("", row["text"])
    report_page_lst = word_tokenize(report_page)
    tokens = []
    for word_ in filter(RE_RUSSIAN_TEXT.match, report_page_lst):
        if word_ and word_ not in stopwords_ru:
            word_ = word_.strip()
            word_ = morph.normal_forms(word_)[0]
            tokens.append(word_)
    cleaned_text.append(" ".join(tokens))
# Out:
# 100%|██████████| 151/151 [00:09<00:00, 15.33it/s]

# %%
df["cleaned_texts"] = cleaned_text
df.to_csv("news.csv.zip")

# %% [markdown]
# # Cosine

# %%
e_topics = pd.read_csv("../topics/e_topic.csv.zip")
s_topics = pd.read_csv("../topics/s_topic.csv.zip")
g_topics = pd.read_csv("../topics/g_topic.csv.zip")
topics_words = pd.concat([e_topics, s_topics, g_topics])
topics_words.head()
# Out:
#       topic                           word  type
# 0  Экология                  аудит системы     1
# 1  Экология                 взаимодействие     1
# 2  Экология                      внедрение     1
# 3  Экология                    воздействие     1
# 4  Экология  восстановительные мероприятия     1

# %%
re_dict = {}
sheets_dict = {}
base_dict = {}

for idx, row in topics_words.iterrows():
    if not sheets_dict.get(row["topic"], False):
        sheets_dict[row["topic"]] = {}
        base_dict[row["topic"]] = {}
    sheets_dict[row["topic"]][row["word"]] = row["type"]
    base_dict[row["topic"]][row["word"]] = 0

for key, val in sheets_dict.items():
    re_dict[key] = re.compile("(" + "(?!\w)|".join(val.keys()) + "(?!\w))")

# %%
df = pd.read_csv("news.csv.zip", index_col=0)
df.head()
# Out:
#                                                  url  \
# 0  https://www.finam.ru/publications/item/neftega...
# 1  https://bonds.finam.ru/news/item/roznichnye-in...
# 2  https://www.finam.ru/publications/item/v-tsena...
# 3  https://www.finam.ru/publications/item/gazprom...
# 4  https://www.finam.ru/publications/item/v-gazpr...
#
#                                                 text  company  \
# 0  Аналитики «Финама» подготовили стратегию по не...  gazprom
# 1  МОСКВА, 26 июл - РИА Новости/Прайм. Высокий ин...  gazprom
# 2  Цены на газ остаются высокими, хотя плавучие х...  gazprom
# 3  «Газпром» в ходе аукциона выиграл крупные газо...  gazprom
# 4  Оценивая перспективы инвестиции в акции «Газпр...  gazprom
#
#                                        cleaned_texts
# 0  аналитик финама подготовить стратегия нефтегаз...
# 1  москва июл риа новости/прайм высокий интерес в...
# 2  цена газ оставаться высокий хотя плавучий хран...
# 3  газпром ход аукцион выиграть крупный газовый у...
# 4  оценивать перспектива инвестиция акция газпром...

# %%
df["company"].value_counts()
# Out:
# gazprom    123
# mmk         28
# Name: company, dtype: int64

# %%
topics = []
for text in tqdm(df["cleaned_texts"].tolist()):
    paragraph_dict = copy.deepcopy(base_dict)
    found_words = False
    for key, regex in re_dict.items():
        words = regex.findall(text)
        for word in words:
            paragraph_dict[key][word] = 1
            found_words = True
    res = {}
    if not found_words:
        res = {key: 0 for key in sheets_dict}
        topics.append({**res, **{"max_score": None, "max_topic": None}})
        continue
    for key, vector in sheets_dict.items():
        sim = cosine_similarity(X=[list(vector.values())], Y=[list(paragraph_dict[key].values())])[0][0]
        res[key] = sim

    topics.append(
        {
            **res,
            **{
                "max_score": max(res.values()),
                "max_topic": max(res, key=lambda k: res[k]),
            },
        }
    )
# Out:
# 100%|██████████| 151/151 [00:05<00:00, 25.97it/s]

# %%
df = df.join(pd.DataFrame(topics))
df.head()
# Out:
#                                                  url  \
# 0  https://www.finam.ru/publications/item/neftega...
# 0  https://www.finam.ru/publications/item/priobre...
# 1  https://bonds.finam.ru/news/item/roznichnye-in...
# 1  https://www.finam.ru/publications/item/mmk-zav...
# 2  https://www.finam.ru/publications/item/v-tsena...
#
#                                                 text  company  \
# 0  Аналитики «Финама» подготовили стратегию по не...  gazprom
# 0  ММК завершила сделку по приобретению шахты им....      mmk
# 1  МОСКВА, 26 июл - РИА Новости/Прайм. Высокий ин...  gazprom
# 1  ММК завершила сделку по приобретению шахты име...      mmk
# 2  Цены на газ остаются высокими, хотя плавучие х...  gazprom
#
#                                        cleaned_texts  Экология    Климат  \
# 0  аналитик финама подготовить стратегия нефтегаз...  0.190117  0.338062
# 0  ммк завершить сделка приобретение шахта тихов ...  0.190117  0.338062
# 1  москва июл риа новости/прайм высокий интерес в...  0.000000  0.102869
# 1  ммк завершить сделка приобретение шахта имя ти...  0.000000  0.102869
# 2  цена газ оставаться высокий хотя плавучий хран...  0.155230  0.154303
#
#     Энергия    Воздух  Вода    Отходы  ...  Обучение и развитие  Оплата труда  \
# 0  0.177705  0.000000   0.0  0.197386  ...                  0.2      0.302660
# 0  0.177705  0.000000   0.0  0.197386  ...                  0.2      0.302660
# 1  0.000000  0.000000   0.0  0.000000  ...                  0.0      0.195366
# 1  0.000000  0.000000   0.0  0.000000  ...                  0.0      0.195366
# 2  0.177705  0.154303   0.0  0.113961  ...                  0.0      0.000000
#
#    Отношения  потребителями  Отношения с потребителями  \
# 0                  0.374166                   0.271448
# 0                  0.374166                   0.271448
# 1                  0.200000                   0.000000
# 1                  0.200000                   0.000000
# 2                  0.200000                   0.102598
#
#    Отношения с работниками  Охрана здоровья  \
# 0                 0.308607         0.244949
# 0                 0.308607         0.244949
# 1                 0.218218         0.141421
# 1                 0.218218         0.141421
# 2                 0.000000         0.000000
#
#    Профсоюзы и коллективные договоры  Трудовые отношения  max_score  \
# 0                           0.146647            0.233052   0.374166
# 0                           0.146647            0.233052   0.374166
# 1                           0.000000            0.113047   0.248452
# 1                           0.000000            0.113047   0.248452
# 2                           0.000000            0.000000   0.200000
#
#                   max_topic
# 0  Отношения  потребителями
# 0  Отношения  потребителями
# 1                    Налоги
# 1                    Налоги
# 2  Отношения  потребителями
#
# [5 rows x 35 columns]

# %% [markdown]
# # Expert

# %%
label2idx = {topic: i for i, topic in enumerate(sorted(topics_words["topic"].unique()))}
idx2label = {i: topic for i, topic in enumerate(sorted(topics_words["topic"].unique()))}

idx2word = {i: word for i, word in enumerate(topics_words["word"].tolist())}
word2idx = defaultdict(list)

for i, word in enumerate(topics_words["word"].tolist()):
    word2idx[word].append(i)

regex = re.compile("(" + "(?!\w)|".join(topics_words["word"].unique()) + "(?!\w))")

# %%
topics_vectors = np.zeros((topics_words["topic"].nunique(), topics_words.shape[0]), dtype=int)

for topic, topic_words in topics_words.groupby("topic")["word"].agg(list).items():
    for word in topic_words:
        for idx in word2idx[word]:
            topics_vectors[label2idx[topic], idx] = 1

# %%
matrix = np.zeros(topics_vectors.shape)
matrix.shape
# Out:
# (29, 4414)

# %%
def fit(vectors, labels):
    for vector, label in zip(vectors, labels):
        for i in range(matrix.shape[0]):
            if i == label2idx[label]:
                matrix[i] += vector
            else:
                matrix[i] -= vector


def test(vectors, labels):
    total = 0
    for vector, label in zip(vectors, labels):
        res = np.argmax(vector @ matrix.T)
        total += label == idx2label[res]
        if label != idx2label[res]:
            print("expected", label, "result", idx2label[res])
    print("accuracy", total / len(labels))

# %%
fit(topics_vectors, list(sorted(topics_words["topic"].unique())))
test(topics_vectors, list(sorted(topics_words["topic"].unique())))
# Out:
# accuracy 1.0

# %%
topics = []
for text in tqdm(df["cleaned_texts"].tolist()):
    vector = np.zeros(matrix.shape[1])
    words = regex.findall(text)
    if len(words) == 0:
        topics.append(None)
        continue
    for word in words:
        vector[word2idx[word]] = 1
    res = np.argmax(vector @ matrix.T)
    topics.append(idx2label[res])
# Out:
# 100%|██████████| 151/151 [00:06<00:00, 22.91it/s]

# %%
df["topic_expert_system"] = topics

# %% [markdown]
# # Sentiment

# %% [markdown]
# ## Dostoevsky

# %%
from dostoevsky.tokenization import RegexTokenizer
from dostoevsky.models import FastTextSocialNetworkModel

tokenizer = RegexTokenizer()
model = FastTextSocialNetworkModel(tokenizer=tokenizer)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
results = model.predict(df["cleaned_texts"].tolist())

# %%
df = df.join(pd.DataFrame(results))
df.head()
# Out:
#                                                  url  \
# 0  https://www.finam.ru/publications/item/neftega...
# 0  https://www.finam.ru/publications/item/priobre...
# 1  https://bonds.finam.ru/news/item/roznichnye-in...
# 1  https://www.finam.ru/publications/item/mmk-zav...
# 2  https://www.finam.ru/publications/item/v-tsena...
#
#                                                 text  company  \
# 0  Аналитики «Финама» подготовили стратегию по не...  gazprom
# 0  ММК завершила сделку по приобретению шахты им....      mmk
# 1  МОСКВА, 26 июл - РИА Новости/Прайм. Высокий ин...  gazprom
# 1  ММК завершила сделку по приобретению шахты име...      mmk
# 2  Цены на газ остаются высокими, хотя плавучие х...  gazprom
#
#                                        cleaned_texts  Экология    Климат  \
# 0  аналитик финама подготовить стратегия нефтегаз...  0.190117  0.338062
# 0  ммк завершить сделка приобретение шахта тихов ...  0.190117  0.338062
# 1  москва июл риа новости/прайм высокий интерес в...  0.000000  0.102869
# 1  ммк завершить сделка приобретение шахта имя ти...  0.000000  0.102869
# 2  цена газ оставаться высокий хотя плавучий хран...  0.155230  0.154303
#
#     Энергия    Воздух  Вода    Отходы  ...  Профсоюзы и коллективные договоры  \
# 0  0.177705  0.000000   0.0  0.197386  ...                           0.146647
# 0  0.177705  0.000000   0.0  0.197386  ...                           0.146647
# 1  0.000000  0.000000   0.0  0.000000  ...                           0.000000
# 1  0.000000  0.000000   0.0  0.000000  ...                           0.000000
# 2  0.177705  0.154303   0.0  0.113961  ...                           0.000000
#
#    Трудовые отношения  max_score                 max_topic  \
# 0            0.233052   0.374166  Отношения  потребителями
# 0            0.233052   0.374166  Отношения  потребителями
# 1            0.113047   0.248452                    Налоги
# 1            0.113047   0.248452                    Налоги
# 2            0.000000   0.200000  Отношения  потребителями
#
#                   topic_expert_system   neutral  negative  positive      skip  \
# 0   Инвестиции и капитальные вложения  0.607673  0.217348  0.103759  0.098089
# 0  Эффективность и производительность  0.607673  0.217348  0.103759  0.098089
# 1               Дивиденды и акционеры  0.294225  0.140346  0.275140  0.168867
# 1   Инвестиции и капитальные вложения  0.294225  0.140346  0.275140  0.168867
# 2         Безопасность и охрана труда  0.835494  0.187143  0.087574  0.039649
#
#      speech
# 0  0.007356
# 0  0.007356
# 1  0.012831
# 1  0.012831
# 2  0.004080
#
# [5 rows x 41 columns]

# %% [markdown]
# ## BERT

# %%
import torch
from transformers import AutoModelForSequenceClassification
from transformers import BertTokenizerFast

tokenizer = BertTokenizerFast.from_pretrained("blanchefort/rubert-base-cased-sentiment")
model = AutoModelForSequenceClassification.from_pretrained("blanchefort/rubert-base-cased-sentiment", return_dict=True)


@torch.no_grad()
def predict(text):
    inputs = tokenizer(text, max_length=512, padding=True, truncation=True, return_tensors="pt")
    outputs = model(**inputs)
    predicted = torch.nn.functional.softmax(outputs.logits, dim=1)
    # predicted = torch.argmax(predicted, dim=1).numpy()
    return predicted
# Out:
# 2023-08-08 16:39:50.710654: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-08 16:39:50.854632: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-08 16:39:51.620981: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
rubert = []
for text in tqdm(df["cleaned_texts"].tolist()):
    rubert.extend(predict(text).tolist())
# Out:
# 100%|██████████| 151/151 [01:09<00:00,  2.18it/s]

# %%
rubert = pd.DataFrame(rubert, columns=["rubert_neutral", "rubert_positive", "rubert_negative"])

# %%
df = df.join(rubert)
df.head()
# Out:
#                                                  url  \
# 0  https://www.finam.ru/publications/item/neftega...
# 0  https://www.finam.ru/publications/item/priobre...
# 1  https://bonds.finam.ru/news/item/roznichnye-in...
# 1  https://www.finam.ru/publications/item/mmk-zav...
# 2  https://www.finam.ru/publications/item/v-tsena...
#
#                                                 text  company  \
# 0  Аналитики «Финама» подготовили стратегию по не...  gazprom
# 0  ММК завершила сделку по приобретению шахты им....      mmk
# 1  МОСКВА, 26 июл - РИА Новости/Прайм. Высокий ин...  gazprom
# 1  ММК завершила сделку по приобретению шахты име...      mmk
# 2  Цены на газ остаются высокими, хотя плавучие х...  gazprom
#
#                                        cleaned_texts  Экология    Климат  \
# 0  аналитик финама подготовить стратегия нефтегаз...  0.190117  0.338062
# 0  ммк завершить сделка приобретение шахта тихов ...  0.190117  0.338062
# 1  москва июл риа новости/прайм высокий интерес в...  0.000000  0.102869
# 1  ммк завершить сделка приобретение шахта имя ти...  0.000000  0.102869
# 2  цена газ оставаться высокий хотя плавучий хран...  0.155230  0.154303
#
#     Энергия    Воздух  Вода    Отходы  ...                 max_topic  \
# 0  0.177705  0.000000   0.0  0.197386  ...  Отношения  потребителями
# 0  0.177705  0.000000   0.0  0.197386  ...  Отношения  потребителями
# 1  0.000000  0.000000   0.0  0.000000  ...                    Налоги
# 1  0.000000  0.000000   0.0  0.000000  ...                    Налоги
# 2  0.177705  0.154303   0.0  0.113961  ...  Отношения  потребителями
#
#                   topic_expert_system   neutral  negative  positive      skip  \
# 0   Инвестиции и капитальные вложения  0.607673  0.217348  0.103759  0.098089
# 0  Эффективность и производительность  0.607673  0.217348  0.103759  0.098089
# 1               Дивиденды и акционеры  0.294225  0.140346  0.275140  0.168867
# 1   Инвестиции и капитальные вложения  0.294225  0.140346  0.275140  0.168867
# 2         Безопасность и охрана труда  0.835494  0.187143  0.087574  0.039649
#
#      speech  rubert_neutral  rubert_positive  rubert_negative
# 0  0.007356        0.815578         0.151188         0.033233
# 0  0.007356        0.815578         0.151188         0.033233
# 1  0.012831        0.820180         0.147689         0.032131
# 1  0.012831        0.820180         0.147689         0.032131
# 2  0.004080        0.180675         0.067849         0.751475
#
# [5 rows x 44 columns]

# %%
df.to_csv("precessed_news.csv.zip")
