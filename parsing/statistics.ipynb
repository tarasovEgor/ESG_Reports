# %%
import re
import os
import json
from collections import defaultdict

import textract
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from tqdm import tqdm

# %%
from pymorphy2 import MorphAnalyzer

# %%
REPORTS_TXT_DIRECTORY = 'reports_txt'
REPORTS_TXT_LEMMATIZED_DIRECTORY = 'reports_txt_lemmatized'
REPORTS_TXT_1000 = 'reports_txt_1000'
REPORTS_TXT_100 = 'reports_txt_100'
EXCLUDE_PATTERNS = re.compile("[A-Za-z0-9!#$%&'()*+,./:;<=>?@[\]^_`{|}~—\"\-]+")
stopwords_ru = stopwords.words("russian")

# %% [markdown]
# ### Лемматизация отчетов

# %%
morph = MorphAnalyzer()

# %%
def lemmatize(doc):
    doc = EXCLUDE_PATTERNS.sub(' ', doc)
    tokens = []
    for token in doc.split():
        if token and token not in stopwords_ru:
            token = token.strip()
            token = morph.normal_forms(token)[0]
            
            tokens.append(token)
    return ' '.join(tokens)

# %%
for report in tqdm(os.listdir(REPORTS_TXT_DIRECTORY)):
    if not report.endswith('.txt'):
            continue
    report_filename = f'{REPORTS_TXT_DIRECTORY}/{report}'
    with open(report_filename) as f:
        report_text = f.read()
    report_text_lemmatized = lemmatize(report_text)
    _, report = report.rsplit('_', maxsplit=1)
    report_lemmatized_filename = f'{REPORTS_TXT_LEMMATIZED_DIRECTORY}/{report}'
    with open(report_lemmatized_filename, 'w') as f:
        f.write(report_text_lemmatized)
# Out:
# 100%|█████████████████████████████████████| 1187/1187 [2:04:42<00:00,  6.30s/it]

# %%
len(os.listdir(REPORTS_TXT_LEMMATIZED_DIRECTORY))
# Out:
# 1186

# %% [markdown]
# ### Статистика по словам

# %%
rep_words_freq = defaultdict(int) # в скольких отчетах употребляется слово
words_freq = defaultdict(int) # сколько раз всего употребляется слово

# %%
for report in tqdm(os.listdir(REPORTS_TXT_LEMMATIZED_DIRECTORY)):
    if not report.endswith('.txt'):
        continue

    report_filename = f'{REPORTS_TXT_LEMMATIZED_DIRECTORY}/{report}'
    with open(report_filename) as f:
        report_text = f.read()
    report_text_lst = word_tokenize(report_text)
    
    if len(report_text_lst) < 40:
        os.remove(report_filename)
        continue

    report_words = set()
    for word in report_text_lst:
        words_freq[word] += 1
        if not word in report_words:
            report_words.add(word)
            rep_words_freq[word] += 1
# Out:
# 100%|███████████████████████████████████████| 1178/1178 [01:43<00:00, 11.37it/s]

# %%
amount_of_reports = len(os.listdir(REPORTS_TXT_LEMMATIZED_DIRECTORY))
amount_of_reports
# Out:
# 1178

# %%
with open('rep_words_freq.json', 'w') as json_file:
    json.dump(rep_words_freq, json_file, indent=4)
    
with open('words_freq.json', 'w') as json_file:
    json.dump(words_freq, json_file, indent=4)

# %%
rep_words_freq_percent = {k: v / amount_of_reports for (k, v) in rep_words_freq.items()}
with open('rep_words_freq_percent.json', 'w') as json_file:
    json.dump(rep_words_freq_percent, json_file, indent=4)

# %%
between_2_and_30 = set()
for key, value in tqdm(rep_words_freq_percent.items()):
    if value >= 0.01 and value <= 0.3:
        between_2_and_30.add(key)
# Out:
# 100%|██████████████████████████████| 143042/143042 [00:00<00:00, 2546375.14it/s]

# %%
len(between_2_and_30)
# Out:
# 19854

# %%
between_2_and_30
# Out:
# {'задержание',
#  'возродить',
#  'целе\xad',
#  'незави\xad',
#  'работни\xad',
#  'краснокамский',
#  'филиальный',
#  'корунд',
#  'самодеятельный',
#  'венчурный',
#  'своеобразный',
#  'приехать',
#  'природо\xad',
#  'роберт',
#  'умерший',
#  'подчас',
#  'убедиться',
#  'биоиндикация',
#  'гипроспецгаз',
#  'пэтф',
#  'псо',
#  'семейство',
#  'мхат',
#  'фбуз',
#  'технополис',
#  'заполярный',
#  'ру\xad',
#  'дз',
#  'излагаться',
#  'юрхаровский',
#  'смолистый',
#  'кузнецов',
#  'крюков',
#  'теплоэлектроцентраль',
#  'гать',
#  'предрейсовый',
#  'повод',
#  'эластомер',
#  'ужесточать',
#  'торможение',
#  'угледобыча',
#  'мун',
#  'трактовка',
#  'акселерационный',
#  'фотопроект',
#  'выбывать',
#  'шамильевич',
#  'отборочный',
#  'табаков',
#  'абк',
#  'ванино',
#  'быт',
#  'пережить',
#  'литр',
#  'тепломеханический',
#  'павлодарский',
#  'физлицо',
#  'нобелевский',
#  'пит',
#  'нераспространение',
#  'обход',
#  'тренный',
#  'консалтинг',
#  'внаём',
#  'аванс',
#  'ай',
#  'ораторский',
#  'мопо',
#  'тепловоз',
#  'переизбыток',
#  'необъективность',
#  'политически',
#  'предоставль',
#  'добровольческий',
#  'эпоха',
#  'данна',
#  'больной',
#  'впредь',
#  'проседание',
#  'замещать',
#  'персонально',
#  'соединительный',
#  'свободненский',
#  'несомненный',
#  'хозспособ',
#  'кабрить',
#  'объездной',
#  'сойти',
#  'сли',
#  'ротировать',
#  'засеять',
#  'чать',
#  'повести',
#  'скользящий',
#  'алёшин',
#  'балтийск',
#  'трап',
#  'посмотреть',
#  'ви',
#  'ордынка',
#  'запускаться',
#  'битумный',
#  'платина',
#  'гпа',
#  'бауман',
#  'трансмутация',
#  'тратить',
#  'подкатегория',
#  'ководитель',
#  'автотехник',
#  'воспрепятствовать',
#  'центробежный',
#  'белоусов',
#  'внутрь',
#  'элегазовый',
#  'вниз',
#  'стремительно',
#  'асмолов',
#  'росгидромет',
#  'массовость',
#  'эндемичный',
#  'авиатехник',
#  'шиться',
#  'дзержинский',
#  'подъёмник',
#  'ядовитый',
#  'запятая',
#  'месячник',
#  'выдерживать',
#  'шушенский',
#  'сверху',
#  'финансо',
#  'обласа',
#  'заблокировать',
#  'нексиа',
#  'пожаробезопасный',
#  'вернуть',
#  'междуна\xad',
#  'витязь',
#  'накапливаться',
#  'результативный',
#  'апартамент',
#  'хронометраж',
#  'кото',
#  'йога',
#  'рительный',
#  'обменный',
#  'директорат',
#  'противоптичий',
#  'всплывать',
#  'той',
#  'точнее',
#  'откр',
#  'муфта',
#  'алерт',
#  'пфр',
#  'сель',
#  'партер',
#  'контентный',
#  'заезд',
#  'биллинга',
#  'видеомониторинг',
#  'сты',
#  'пометить',
#  'нефтеотдача',
#  'спонтанный',
#  'гусеничный',
#  'газопроводный',
#  'неуклонно',
#  'томскнефтехим',
#  'мара',
#  'ск',
#  'уточняться',
#  'недостаточность',
#  'мфр',
#  'ресур\xad',
#  'имитация',
#  'глубинный',
#  'усложниться',
#  'фокусирование',
#  'юбиляр',
#  'ологический',
#  'документироваться',
#  'ауди\xad',
#  'распознать',
#  'ферганский',
#  'балласт',
#  'кухонный',
#  'реждения',
#  'непротиворечивость',
#  'страция',
#  'пн',
#  'пароходство',
#  'сантехнический',
#  'вал',
#  'созываться',
#  'гва',
#  'гроза',
#  'сигнализация',
#  'облик',
#  'владимирский',
#  'соз',
#  'госзакупка',
#  'незакрытый',
#  'выезд',
#  'кириши',
#  'татарин',
#  'распродажа',
#  'ого',
#  'маршал',
#  'длинномерный',
#  'промстоковый',
#  'столярный',
#  'реконфигурация',
#  'видеоконференцсвязь',
#  'севастополь',
#  'экспозиционный',
#  'инспектор',
#  'эвакуационный',
#  'участковый',
#  'тёпа',
#  'полуостров',
#  'норильск',
#  'стадо',
#  'согласованность',
#  'ростехнология',
#  'универсал',
#  'воин',
#  'пайщик',
#  'ведомость',
#  'травматология',
#  'плоскость',
#  'кон\xad',
#  'предоплатить',
#  'высокообогащённый',
#  'инфекционный',
#  'трезвый',
#  'профес',
#  'афанасьев',
#  'номинироваться',
#  'природопользователь',
#  'мультимедийный',
#  'полётный',
#  'внешнеторговый',
#  'сост',
#  'герой',
#  'кыргызский',
#  'инфографик',
#  'спо\xad',
#  'нервный',
#  'мама',
#  'ферленг',
#  'стеллаж',
#  'фосфатный',
#  'грузоподъёмный',
#  'гока',
#  'пдд',
#  'пальный',
#  'дународный',
#  'покупательский',
#  'зочный',
#  'представимый',
#  'тревожность',
#  'превосходящий',
#  'зание',
#  'ворлдскиллс',
#  'роторный',
#  'богатый',
#  'электропотребление',
#  'штанга',
#  'электрометаллургический',
#  'выборка',
#  'трубчатый',
#  'выщелачивание',
#  'камаз',
#  'каскадный',
#  'тгк\xad',
#  'спиртной',
#  'ски',
#  'асуп',
#  'чум',
#  'пдзк',
#  'начинающий',
#  'исправление',
#  'низм',
#  'когенерация',
#  'психиатрический',
#  'формулировать',
#  'деза',
#  'творение',
#  'саморазвитие',
#  'альфастрахование',
#  'эндемик',
#  'сшить',
#  'пропитка',
#  'курорт',
#  'посредничество',
#  'разливка',
#  'расконсервация',
#  'слитковый',
#  'флотореагент',
#  'трансляция',
#  'поражающий',
#  'достоевский',
#  'лыжный',
#  'сре\xad',
#  'переезжать',
#  'видный',
#  'приразломный',
#  'благо\xad',
#  'инициирование',
#  'экспедиторский',
#  'рудования',
#  'плавание',
#  'кооперационный',
#  'несвойственный',
#  'камеральный',
#  'числовой',
#  'ническим',
#  'отдавать',
#  'университетский',
#  'признательность',
#  'диджитализация',
#  'выяснять',
#  'барсучковский',
#  'поощрить',
#  'приповерхностный',
#  'генезис',
#  'биография',
#  'фотоконкурс',
#  'интернациональный',
#  'чистопольский',
#  'стрелка',
#  'даваться',
#  'козин',
#  'страновой',
#  'елховский',
#  'проём',
#  'достигаемый',
#  'откачиваться',
#  'подтвердиться',
#  'газотранспортный',
#  'корабль',
#  'туган',
#  'интервьюирование',
#  'металлургия',
#  'вакуум',
#  'виртуализация',
#  'хейнекен',
#  'бо́льшать',
#  'речка',
#  'корсаковский',
#  'браконьер',
#  'узк',
#  'коммерция',
#  'засушливый',
#  'краснодар',
#  'ассоциированный',
#  'июн',
#  'ставщик',
#  'спективный',
#  'десант',
#  'калмыцкий',
#  'покраска',
#  'радиоэлектроника',
#  'обследовать',
#  'ркк',
#  'депозит',
#  'дожимной',
#  'точечный',
#  'генераторный',
#  'увязывать',
#  'драга',
#  'инна',
#  'этилен',
#  'кация',
#  'водообеспечение',
#  'император',
#  'конго',
#  'дубай',
#  'кобальтовый',
#  'кото\xad',
#  'молния',
#  'кошелёк',
#  'госзаказ',
#  'обезвредить',
#  'травмированный',
#  'радиометр',
#  'костин',
#  'фицировать',
#  'дендрологический',
#  'приют',
#  'седакова',
#  'пдк',
#  'британский',
#  'приумножение',
#  'энина',
#  'петух',
#  'ммнк',
#  'рс',
#  'пышма',
#  'исаев',
#  'ника',
#  'фрс',
#  'превращать',
#  'самара',
#  'тгу',
#  'сельхозтехника',
#  'сверхурочный',
#  'бутырский',
#  'продувочный',
#  'обеззараживать',
#  'арс',
#  'волнующий',
#  'администрировать',
#  'культивировать',
#  'представительский',
#  'миг',
#  'копирование',
#  'образовывать',
#  'измельчаться',
#  'угра',
#  'озвучиваться',
#  'релевантность',
#  'причастность',
#  'холмск',
#  'омский',
#  'врачебный',
#  'дворцовый',
#  'богородица',
#  'подведомственный',
#  'грубый',
#  'зимник',
#  'печора',
#  'трудно',
#  'коррелировать',
#  'салон',
#  'ямальский',
#  'нейтрализация',
#  'ации',
#  'без\xad',
#  'добровольчество',
#  'зпиф',
#  'проф',
#  'молниезащита',
#  'губа',
#  'кустовой',
#  'малоотходный',
#  'грузоотправитель',
#  'наладчик',
#  'гбпоу',
#  'нир',
#  'нюксенский',
#  'привитие',
#  'минь',
#  'выдвигаться',
#  'нерам',
#  'сахг',
#  'бт',
#  'необоснованно',
#  'прессование',
#  'шахтный',
#  'бря',
#  'воскресный',
#  'ось',
#  'тнк',
#  'прокоп',
#  'сталь',
#  'сороковой',
#  'теплофизика',
#  'хант',
#  'личность',
#  'киум',
#  'сознать',
#  'воспроизводить',
#  'почувствовать',
#  'проранжировать',
#  'гидроспецгеология',
#  'потребоваться',
#  'информативный',
#  'отнесение',
#  'радиохимический',
#  'дисконтный',
#  'эскалация',
#  'салават',
#  'очертить',
#  'гидродинамика',
#  'детёныш',
#  'вилючинск',
#  'разногласие',
#  'сфе',
#  'швец',
#  'выпадать',
#  'мпр',
#  'сменность',
#  'добросовестно',
#  'стандартизованный',
#  'егдс',
#  'сохра',
#  'проблематика',
#  'опуститься',
#  'инновый',
#  'венесуэла',
#  'автономия',
#  'вывозной',
#  'биоразлагать',
#  'ваа',
#  'двое',
#  'дойти',
#  'рять',
#  'запад',
#  'смбтиоз',
#  'пятьдесят',
#  'пеня',
#  'кировэнерго',
#  'раствор',
#  'сырьём',
#  'терминальный',
#  'обин',
#  'табак',
#  'информатизация',
#  'мышь',
#  'ритейл',
#  'крыша',
#  'сортировать',
#  'медиалогия',
#  'адаптационный',
#  'противофонтанный',
#  'микроклимат',
#  'логин',
#  'присоединяться',
#  'выкладываться',
#  'таганрог',
#  'осматривать',
#  'бородино',
#  'переносить',
#  'экто',
#  'экспресс',
#  'когнитивный',
#  'триста',
#  'манипулирование',
#  'водонагнетательный',
#  'иркутскэнерго',
#  'нфа',
#  'правообладатель',
#  'медь',
#  'ккал',
#  'азбука',
#  'ноглик',
#  'вначале',
#  'декомпозировать',
#  'сыпучий',
#  'комиссионный',
#  'мультимедиа',
#  'апробированный',
#  'глубоко',
#  'генподрядчик',
#  'шматко',
#  'изба',
#  'охотский',
#  'поистине',
#  'осевой',
#  'пбу',
#  'указываться',
#  'бутилкаучук',
#  'отличиться',
#  'магний',
#  'везти',
#  'дуб',
#  'оуп',
#  'подведение',
#  'хозфекальный',
#  'отправка',
#  'ботна',
#  'рекуператор',
#  'рыбохозяйственный',
#  'амк',
#  'усугубляться',
#  'логика',
#  'торпедо',
#  'ранжироваться',
#  'карго',
#  'дельфин',
#  'цтз',
#  'ман',
#  'рассвет',
#  'вор',
#  'иванов',
#  'уве',
#  'альянстрансат',
#  'уссурийский',
#  'третьяк',
#  'тэс',
#  'щёлково',
#  'отчество',
#  'бункеровочный',
#  'вкль',
#  'необеспеченный',
#  'фракция',
#  'торговать',
#  'элемаш',
#  'дотация',
#  'топ‑',
#  'пасный',
#  'звучание',
#  'воспитывать',
#  'дислокация',
#  'радиозавод',
#  'ивл',
#  'перинатальный',
#  'химически',
#  'станислав',
#  'преподносить',
#  'приблизительно',
#  'ровительный',
#  'взаимозависимость',
#  'пользовательский',
#  'пропилен',
#  'асбест',
#  'волновать',
#  'азотный',
#  'зако\xad',
#  'мвт·ча',
#  'карабашский',
#  'расторжение',
#  'образо\xad',
#  'интегратор',
#  'стрела',
#  'исследовать',
#  'саморегулируемый',
#  'тив',
#  'решетчатый',
#  'населять',
#  'щитной',
#  'кстово',
#  'радовать',
#  'закрывать',
#  'ответчик',
#  'отзываться',
#  'италия',
#  'поясняться',
#  'рассредоточение',
#  'отсортировать',
#  'радиотехник',
#  'самоходный',
#  'евросоюз',
#  'ускоряться',
#  'черновик',
#  'хакасэнерго',
#  'молоко',
#  'собор',
#  'плекс',
#  'училище',
#  'словацкий',
#  'выражаться',
#  'концессионный',
#  'нептун',
#  'мотоциклетный',
#  'нал',
#  'долголетний',
#  'крепёж',
#  'материалоёмкость',
#  'интермодальный',
#  'кина',
#  'иловый',
#  'тру\xad',
#  'континентальный',
#  'соор',
#  'ваб',
#  'браковать',
#  'журналистский',
#  'челлендж',
#  'монтировать',
#  'расплавить',
#  'немедленно',
#  'отсрочить',
#  'макс',
#  'пресный',
#  'соотнесение',
#  'грозить',
#  'ративный',
#  'мужской',
#  'инфра\xad',
#  'запах',
#  'елизавета',
#  'пирог',
#  'нефтепроводный',
#  'жигулёвск',
#  'экстремально',
#  'зоммера',
#  'татарстан',
#  'познание',
#  'задний',
#  'хакасэнергосбыт',
#  'крачка',
#  'фильтрация',
#  'диффузия',
#  'присудить',
#  'запатентовать',
#  'бк',
#  'шар',
#  'удостоверить',
#  'нгк',
#  'содовый',
#  'высокогорный',
#  'вызывать',
#  'пушистый',
#  'делять',
#  'нтв',
#  'генетический',
#  'окфс',
#  'заводский',
#  'оптимистично',
#  'обозрение',
#  'фи',
#  'ставрополь',
#  'известняк',
#  'распространять',
#  'приспосабливаться',
#  'внешкольный',
#  'теракт',
#  'торф',
#  'знаменовать',
#  'захватывать',
#  'вуктыльский',
#  'аномальный',
#  'дневный',
#  'бельгия',
#  'полина',
#  'граничить',
#  'запрашивать',
#  'потанин',
#  'сибиряк',
#  'тыл',
#  'рыборазводный',
#  'оскорбительный',
#  'трение',
#  'лада',
#  'зов',
#  'квант',
#  'вопро',
#  'зультат',
#  'озвучивать',
#  'хирургия',
#  'ттм',
#  'разгосударствление',
#  'гареев',
#  'отменный',
#  'нерелевантный',
#  'уче',
#  'тко',
#  'подзарядка',
#  'трихлордифенил',
#  'изолятор',
#  'непродление',
#  'порча',
#  'берёза',
#  'детишки',
#  'ствуют',
#  'неоправданный',
#  'наслать',
#  'святослав',
#  'видеоаналитик',
#  'подрост',
#  'приезжать',
#  'овладение',
#  'мгновенно',
#  'гидро',
#  'мгимо',
#  'инв',
#  'карда',
#  'готовка',
#  'мена',
#  'поэтесса',
#  'неаудировать',
#  'выключатель',
#  'панов',
#  'постройка',
#  'вмешательство',
#  'изменчивый',
#  'гравитационный',
#  'откуда',
#  'аргументация',
#  'разумно',
#  'действительный',
#  'кустарник',
#  'стройбаза',
#  'коммутация',
#  'солодовня',
#  'просперити',
#  'раковина',
#  'уязвимость',
#  'датировать',
#  'изъявить',
#  'рпн',
#  'бурятия',
#  'актуально',
#  'недоотпуск',
#  'кид',
#  'ствие',
#  'кристиан',
#  'промбезопасность',
#  'тбр',
#  'минусинск',
#  'кент',
#  'бакалавриат',
#  'ортопедический',
#  'нортгаз',
#  'уничтожение',
#  'картотека',
#  'ентировать',
#  'метанол',
#  'водопровод',
#  'долго',
#  'подкласс',
#  'рама',
#  'сопредельный',
#  'подсчёт',
#  'смысл',
#  'видеоаналитика',
#  'дозовый',
#  'обла',
#  'возобновиться',
#  'хаз',
#  'промый',
#  'исправность',
#  'капремонт',
#  'любительский',
#  'гоночный',
#  'наградной',
#  'вынесение',
#  'дима',
#  'фреска',
#  'претерпеть',
#  'вредоносный',
#  'огнестойкий',
#  'деформация',
#  'гостиничный',
#  'каче\xad',
#  'вательный',
#  'рза',
#  'кгн',
#  'планировщик',
#  'дования',
#  'геоботанический',
#  'щедрый',
#  'колорит',
#  'беллоно',
#  'тивный',
#  'эндокринный',
#  'краска',
#  'нм',
#  'реликтовый',
#  'татнефтеснаб',
#  'совкомбанк',
#  'можный',
#  'струмент',
#  'теплота',
#  'землевладелец',
#  'рыболовство',
#  'казатомпром',
#  'отнюдь',
#  'выживаемость',
#  'лепёс',
#  'декларироваться',
#  'пре\xad',
#  'фессия',
#  'нагрузочный',
#  'кемерово',
#  'тдж',
#  'рецепт',
#  'неизбежно',
#  'рассылаться',
#  'гомельский',
#  'автошкола',
#  'преображенский',
#  'усматривать',
#  'креативный',
#  'разлом',
#  'близ',
#  'церн',
#  'ля',
#  'мошенник',
#  'обеспечь',
#  'оа',
#  'воссоздать',
#  'предстоять',
#  'поменять',
#  'внутриквартальный',
#  'кс',
#  'перемычка',
#  'росгазификация',
#  'байкал',
#  'краеугольный',
#  'биатлонный',
#  'уроран',
#  'зпк',
#  'чиваться',
#  'глинозём',
#  'шевчук',
#  'пермь',
#  'приумножить',
#  'приазовский',
#  'рыбинск',
#  'дачный',
#  'лабытнанги',
#  'озеленить',
#  'отказывать',
#  'корпора\xad',
#  'протестировать',
#  'дифторхлорметан',
#  'закупаться',
#  'даться',
#  'определиться',
#  'габарит',
#  'семестр',
#  'партизанск',
#  'ость',
#  'ация',
#  'опера\xad',
#  'виброуплотнение',
#  'сериал',
#  'заметить',
#  'крепь',
#  'агитационный',
#  'нестабильный',
#  'гл',
#  'палитра',
#  'предметно',
#  'оптимистичный',
#  'антропология',
#  'проводка',
#  'базисный',
#  'накопиться',
#  'проявиться',
#  'дешёвый',
#  'диспансеризация',
#  'вынудить',
#  'автоцистерна',
#  'педагогика',
#  'турбогенераторный',
#  'итэр',
#  'вагнер',
#  'тарифообразование',
#  'задумать',
#  'артек',
#  'кутафин',
#  'туберкулёз',
#  'рубрика',
#  'второстепенный',
#  'фотореле',
#  'проконтролировать',
#  'узбекский',
#  'частное',
#  'кадет',
#  'пластина',
#  'наполнение',
#  'тамбовский',
#  'респ',
#  'бенефициарный',
#  'шум',
#  'прочесть',
#  'саморегулирование',
#  'еусотня',
#  'пнк',
#  'пароход',
#  'каких\xadлибо',
#  'оградить',
#  'пауза',
#  'гуанчжоу',
#  'веня',
#  'межфункциональный',
#  'многопластовый',
#  'конфигурация',
#  'шёлковый',
#  'славный',
#  'слава',
#  'дикий',
#  'неразрушающий',
#  'приме\xad',
#  'выпускаться',
#  'брошюра',
#  'биотопливный',
#  'стрешинский',
#  'башня',
#  'чин',
#  'теплоход',
#  'аскуэ',
#  'социология',
#  'хотеться',
#  'суриков',
#  'дегтярёв',
#  'дея\xad',
#  'забалансовый',
#  'макси\xad',
#  'транспарентный',
#  'отвезти',
#  'изготавливать',
#  'болотный',
#  'адаптироваться',
#  ...}

# %%
for report in tqdm(os.listdir(REPORTS_TXT_LEMMATIZED_DIRECTORY)[:1000]):
    if not report.endswith('.txt'):
        continue
    report_filename = f'{REPORTS_TXT_LEMMATIZED_DIRECTORY}/{report}'
    with open(report_filename) as f:
        report_text = f.read()
    report_text_lst = word_tokenize(report_text)
    report_words = [report_word for report_word in report_text_lst if report_word in between_2_and_30]
    new_report_filename = f'{REPORTS_TXT_1000}/{report}'
    with open(new_report_filename, 'w') as f:
        f.write(' '.join(report_words))
        
for report in tqdm(os.listdir(REPORTS_TXT_LEMMATIZED_DIRECTORY)[1000:]):
    if not report.endswith('.txt'):
        continue
    report_filename = f'{REPORTS_TXT_LEMMATIZED_DIRECTORY}/{report}'
    with open(report_filename) as f:
        report_text = f.read()
    report_text_lst = word_tokenize(report_text)
    report_words = [report_word for report_word in report_text_lst if report_word in between_2_and_30]
    new_report_filename = f'{REPORTS_TXT_100}/{report}'
    with open(new_report_filename, 'w') as f:
        f.write(' '.join(report_words))
# Out:
# 100%|███████████████████████████████████████| 1000/1000 [01:23<00:00, 11.93it/s]
# 100%|█████████████████████████████████████████| 178/178 [00:14<00:00, 11.92it/s]

# %% [markdown]
# ### Переходим в kaggle

# %% [markdown]
# [блокнот в kaggle](https://www.kaggle.com/code/michaelyashchenko/top2vec)

# %% [markdown]
# ### Убираем имена компаний

# %%
import pandas as pd

# %%
rspp_df = pd.read_csv('rspp_reports.csv')
rspp_df.head()
# Out:
#    Unnamed: 0                 компания                        сектор   год  \
# 0           0                     РУДН  Образование, здравоохранение  2021
# 1           1         ОАО "МРСК Урала"                    Энергетика  2021
# 2           2     ПАО "Россети Сибирь"                    Энергетика  2021
# 3           3         ПАО "Россети Юг"                    Энергетика  2021
# 4           4  ПАО «Россети Ленэнерго»                    Энергетика  2021
#
#   тип отчета                              ссылка на отчет
# 0        ОУР  /download/7033aa33d6bfc2f5e069f547a5b15109/
# 1         ИО  /download/af503e07dd6b861d1ed3048c36868cc9/
# 2         ИО  /download/57becde4be827f45bedf2a46f58d793a/
# 3         ИО  /download/851fbaea09387885cefa38bd3b6838f3/
# 4         ИО  /download/2034b8c8e84e4bba78049bdd976fc122/

# %%
company_names = list(rspp_df['компания'])

# %%
EXCLUDE_PATTERNS = re.compile("[A-Za-z0-9!#$%&'()*+,./:;<=>?@[\]^_`{|}~—\"\-\«\»]+")

def lemmatize_name(company_name):
    comapny_name = EXCLUDE_PATTERNS.sub('', company_name)
    tokens = set()
    for token in comapny_name.split():
        if token and token not in stopwords_ru:
            token = token.strip()
            token = morph.normal_forms(token)[0]    
            tokens.add(token)
    return tokens

# %%
lemmatized_company_names = set()
for company_name in tqdm(company_names):
    lemmatized_company_names.update(lemmatize_name(company_name))
# Out:
# 100%|█████████████████████████████████████| 1388/1388 [00:01<00:00, 1118.49it/s]

# %%
len(lemmatized_company_names)
# Out:
# 324

# %%
lemmatized_company_names
# Out:
# {'авиакомпания',
#  'агентство',
#  'ак',
#  'акб',
#  'акига',
#  'алмазэргиэнбанк',
#  'алрос',
#  'альфабанк',
#  'алюминиевый',
#  'амвэя',
#  'ангарский',
#  'анк',
#  'ао',
#  'архангельский',
#  'ас',
#  'асэ',
#  'атомпроект',
#  'атомредметзолото',
#  'атомэнергомаш',
#  'атомэнергопроект',
#  'атомэнергопром',
#  'афк',
#  'ашан',
#  'аэропорт',
#  'аэрофлот',
#  'балтика',
#  'банк',
#  'барс',
#  'бат',
#  'башнефть',
#  'бизнес',
#  'билайн',
#  'биржа',
#  'бифид',
#  'благотворительный',
#  'богословский',
#  'бренд',
#  'брусника',
#  'бумажный',
#  'бф',
#  'виктория',
#  'владивостокский',
#  'внипиэт',
#  'волга',
#  'волгателек',
#  'волжский',
#  'восток',
#  'втб',
#  'выксунский',
#  'вымпелком',
#  'вэб',
#  'газ',
#  'газпром',
#  'газпромбанк',
#  'гарантинвест',
#  'генерировать',
#  'геннадий',
#  'гидропресс',
#  'гк',
#  'гмк',
#  'гнц',
#  'головной',
#  'гольцблат',
#  'городской',
#  'госкорпорация',
#  'государственный',
#  'группа',
#  'грэс',
#  'гтлк',
#  'губкин',
#  'дания',
#  'детский',
#  'дивизион',
#  'евразийский',
#  'еврохим',
#  'елена',
#  'енисейский',
#  'еэс',
#  'желдортранс',
#  'завод',
#  'зао',
#  'зарубежнефть',
#  'золото',
#  'ик',
#  'илим',
#  'имииафрикантовый',
#  'имя',
#  'инжиниринговый',
#  'инккапитал',
#  'институт',
#  'интер',
#  'интернэшнл',
#  'информация',
#  'иркутск',
#  'казаньоргсинтез',
#  'казмунайгаз',
#  'калининградский',
#  'камаз',
#  'касперский',
#  'кб',
#  'кемикалс',
#  'ковровский',
#  'комбинат',
#  'коммерческий',
#  'коммунальный',
#  'компания',
#  'комстаротс',
#  'концерн',
#  'корпорация',
#  'красцветмет',
#  'крафтфудс',
#  'кредитный',
#  'кристалл',
#  'кубань',
#  'кузбассэнерго',
#  'лаборатория',
#  'ленэнерго',
#  'леруа',
#  'лпк',
#  'лср',
#  'лукойл',
#  'магнит',
#  'мвидео',
#  'мдмбанк',
#  'мегафон',
#  'международный',
#  'межрегиональный',
#  'мерлен',
#  'металлоинвест',
#  'металлургический',
#  'метафракс',
#  'механический',
#  'мир',
#  'ммк',
#  'монди',
#  'мон’дэлиса',
#  'моррис',
#  'мосводоканал',
#  'московский',
#  'мрск',
#  'мрф',
#  'мсп',
#  'мтс',
#  'муниципальный',
#  'мхк',
#  'научноисследовательский',
#  'недвижимость',
#  'неманский',
#  'нестля',
#  'нефть',
#  'ниаэп',
#  'нижнекамскнефтехим',
#  'нииар',
#  'никель',
#  'нипигаз',
#  'ниу',
#  'нк',
#  'нлмк',
#  'новатэк',
#  'новогор',
#  'новосибирский',
#  'новый',
#  'нордиск',
#  'норильский',
#  'оао',
#  'общероссийский',
#  'объединение',
#  'огк',
#  'окб',
#  'окбм',
#  'около',
#  'омк',
#  'они',
#  'ооо',
#  'отраслевой',
#  'пао',
#  'партнёр',
#  'пассажирский',
#  'пейп',
#  'пепеляев',
#  'петропавловск',
#  'пивоваренный',
#  'пивоваров',
#  'пигмент',
#  'пик',
#  'по',
#  'полиметалл',
#  'полюс',
#  'почта',
#  'приборостроение',
#  'приволжье',
#  'прикамье',
#  'работодатель',
#  'рао',
#  'распадский',
#  'распределительный',
#  'ргу',
#  'регион',
#  'реновый',
#  'ржд',
#  'рксхолдинг',
#  'роза',
#  'рольф',
#  'росатом',
#  'росводоканал',
#  'роснефть',
#  'россеть',
#  'российский',
#  'россия',
#  'ростелеком',
#  'ростёха',
#  'росэнергоатом',
#  'рудна',
#  'русало',
#  'русгидро',
#  'руссинвест',
#  'руссия',
#  'русый',
#  'русь',
#  'рф',
#  'рыбак',
#  'рязанский',
#  'сабмиллер',
#  'санофироссия',
#  'сахалин',
#  'сбербанк',
#  'свез',
#  'севергазпром',
#  'севернефтегазпром',
#  'северозапад',
#  'северсталь',
#  'сервис',
#  'сетевой',
#  'сзлк',
#  'сибирь',
#  'сибурхолдинг',
#  'система',
#  'ситибанк',
#  'ситроникс',
#  'совкомбанк',
#  'солидарность',
#  'социальный',
#  'союз',
#  'спбаэп',
#  'специализировать',
#  'спина',
#  'суал',
#  'сургутнефтегаз',
#  'суэк',
#  'схк',
#  'сыктывкарский',
#  'такед',
#  'таманьнефтегаз',
#  'татнефть',
#  'твэл',
#  'тгк',
#  'телекоммуникационный',
#  'тело',
#  'территориальный',
#  'техснабэкспорт',
#  'тимченко',
#  'тмк',
#  'тнк',
#  'тнквр',
#  'тоаз',
#  'трансаэро',
#  'трансгаз',
#  'транснефть',
#  'тюмень',
#  'университет',
#  'урал',
#  'уралкалий',
#  'уралсиб',
#  'уральский',
#  'урсабанк',
#  'ухта',
#  'фгк',
#  'федеральный',
#  'ферреро',
#  'фиабанк',
#  'филиал',
#  'филип',
#  'фк',
#  'фонд',
#  'фортум',
#  'фосагро',
#  'фпк',
#  'фск',
#  'химик',
#  'химический',
#  'химконцентрат',
#  'холдинг',
#  'хутор',
#  'целлюлознобумажный',
#  'целлюлозный',
#  'цемент',
#  'центр',
#  'центральный',
#  'центринвест',
#  'черкизовый',
#  'чусовской',
#  'шелл',
#  'шереметьево',
#  'щуровский',
#  'экономика',
#  'эксонмобила',
#  'электролизный',
#  'электрохимический',
#  'электроэнергетика',
#  'энела',
#  'энергетический',
#  'энергохолдинг',
#  'энерджи',
#  'эсэфай',
#  'юг',
#  'южнороссийский',
#  'южный',
#  'юкос',
#  'юникредитбанк',
#  'юнипро',
#  'юридический',
#  'яндекс',
#  'янтарный',
#  'ятэк'}

# %%
with open('cn_usual.txt') as f:
    keep_cn = set(map(lambda w: w.strip(), f.read().split(',')))
keep_cn
# Out:
# {'авиакомпания',
#  'агентство',
#  'аэропорт',
#  'банк',
#  'бизнес',
#  'биржа',
#  'благотворительный',
#  'богословский',
#  'бренд',
#  'брусника',
#  'бумажный',
#  'газ',
#  'городской',
#  'госкорпорация',
#  'государственный',
#  'группа',
#  'детский',
#  'завод',
#  'золото',
#  'имя',
#  'институт',
#  'комбинат',
#  'коммерческий',
#  'коммунальный',
#  'компания',
#  'концерн',
#  'корпорация',
#  'кредитный',
#  'кристалл',
#  'лаборатория',
#  'магнит',
#  'международный',
#  'межрегиональный',
#  'механический',
#  'мир',
#  'муниципальный',
#  'научноисследовательский',
#  'недвижимость',
#  'нефть',
#  'никель',
#  'новый',
#  'общероссийский',
#  'отраслевой',
#  'партнёр',
#  'пассажирский',
#  'полюс',
#  'почта',
#  'приборостроение',
#  'работодатель',
#  'распределительный',
#  'регион',
#  'роза',
#  'рыбак',
#  'северозапад',
#  'сервис',
#  'сетевой',
#  'солидарность',
#  'социальный',
#  'союз',
#  'специализировать',
#  'спина',
#  'телекоммуникационный',
#  'тело',
#  'территориальный',
#  'университет',
#  'федеральный',
#  'фонд',
#  'химик',
#  'химический',
#  'холдинг',
#  'хутор',
#  'целлюлознобумажный',
#  'целлюлозный',
#  'цемент',
#  'центр',
#  'центральный',
#  'экономика',
#  'электролизный',
#  'электрохимический',
#  'электроэнергетика',
#  'энергетический',
#  'юг',
#  'южный',
#  'юридический',
#  'янтарный'}

# %%
lemmatized_company_names = lemmatized_company_names - keep_cn
len(lemmatized_company_names)
# Out:
# 239

# %%
lemmatized_company_names
# Out:
# {'ак',
#  'акб',
#  'акига',
#  'алмазэргиэнбанк',
#  'алрос',
#  'альфабанк',
#  'алюминиевый',
#  'амвэя',
#  'ангарский',
#  'анк',
#  'ао',
#  'архангельский',
#  'ас',
#  'асэ',
#  'атомпроект',
#  'атомредметзолото',
#  'атомэнергомаш',
#  'атомэнергопроект',
#  'атомэнергопром',
#  'афк',
#  'ашан',
#  'аэрофлот',
#  'балтика',
#  'барс',
#  'бат',
#  'башнефть',
#  'билайн',
#  'бифид',
#  'бф',
#  'виктория',
#  'владивостокский',
#  'внипиэт',
#  'волга',
#  'волгателек',
#  'волжский',
#  'восток',
#  'втб',
#  'выксунский',
#  'вымпелком',
#  'вэб',
#  'газпром',
#  'газпромбанк',
#  'гарантинвест',
#  'генерировать',
#  'геннадий',
#  'гидропресс',
#  'гк',
#  'гмк',
#  'гнц',
#  'головной',
#  'гольцблат',
#  'грэс',
#  'гтлк',
#  'губкин',
#  'дания',
#  'дивизион',
#  'евразийский',
#  'еврохим',
#  'елена',
#  'енисейский',
#  'еэс',
#  'желдортранс',
#  'зао',
#  'зарубежнефть',
#  'ик',
#  'илим',
#  'имииафрикантовый',
#  'инжиниринговый',
#  'инккапитал',
#  'интер',
#  'интернэшнл',
#  'информация',
#  'иркутск',
#  'казаньоргсинтез',
#  'казмунайгаз',
#  'калининградский',
#  'камаз',
#  'касперский',
#  'кб',
#  'кемикалс',
#  'ковровский',
#  'комстаротс',
#  'красцветмет',
#  'крафтфудс',
#  'кубань',
#  'кузбассэнерго',
#  'ленэнерго',
#  'леруа',
#  'лпк',
#  'лср',
#  'лукойл',
#  'мвидео',
#  'мдмбанк',
#  'мегафон',
#  'мерлен',
#  'металлоинвест',
#  'металлургический',
#  'метафракс',
#  'ммк',
#  'монди',
#  'мон’дэлиса',
#  'моррис',
#  'мосводоканал',
#  'московский',
#  'мрск',
#  'мрф',
#  'мсп',
#  'мтс',
#  'мхк',
#  'неманский',
#  'нестля',
#  'ниаэп',
#  'нижнекамскнефтехим',
#  'нииар',
#  'нипигаз',
#  'ниу',
#  'нк',
#  'нлмк',
#  'новатэк',
#  'новогор',
#  'новосибирский',
#  'нордиск',
#  'норильский',
#  'оао',
#  'объединение',
#  'огк',
#  'окб',
#  'окбм',
#  'около',
#  'омк',
#  'они',
#  'ооо',
#  'пао',
#  'пейп',
#  'пепеляев',
#  'петропавловск',
#  'пивоваренный',
#  'пивоваров',
#  'пигмент',
#  'пик',
#  'по',
#  'полиметалл',
#  'приволжье',
#  'прикамье',
#  'рао',
#  'распадский',
#  'ргу',
#  'реновый',
#  'ржд',
#  'рксхолдинг',
#  'рольф',
#  'росатом',
#  'росводоканал',
#  'роснефть',
#  'россеть',
#  'российский',
#  'россия',
#  'ростелеком',
#  'ростёха',
#  'росэнергоатом',
#  'рудна',
#  'русало',
#  'русгидро',
#  'руссинвест',
#  'руссия',
#  'русый',
#  'русь',
#  'рф',
#  'рязанский',
#  'сабмиллер',
#  'санофироссия',
#  'сахалин',
#  'сбербанк',
#  'свез',
#  'севергазпром',
#  'севернефтегазпром',
#  'северсталь',
#  'сзлк',
#  'сибирь',
#  'сибурхолдинг',
#  'система',
#  'ситибанк',
#  'ситроникс',
#  'совкомбанк',
#  'спбаэп',
#  'суал',
#  'сургутнефтегаз',
#  'суэк',
#  'схк',
#  'сыктывкарский',
#  'такед',
#  'таманьнефтегаз',
#  'татнефть',
#  'твэл',
#  'тгк',
#  'техснабэкспорт',
#  'тимченко',
#  'тмк',
#  'тнк',
#  'тнквр',
#  'тоаз',
#  'трансаэро',
#  'трансгаз',
#  'транснефть',
#  'тюмень',
#  'урал',
#  'уралкалий',
#  'уралсиб',
#  'уральский',
#  'урсабанк',
#  'ухта',
#  'фгк',
#  'ферреро',
#  'фиабанк',
#  'филиал',
#  'филип',
#  'фк',
#  'фортум',
#  'фосагро',
#  'фпк',
#  'фск',
#  'химконцентрат',
#  'центринвест',
#  'черкизовый',
#  'чусовской',
#  'шелл',
#  'шереметьево',
#  'щуровский',
#  'эксонмобила',
#  'энела',
#  'энергохолдинг',
#  'энерджи',
#  'эсэфай',
#  'южнороссийский',
#  'юкос',
#  'юникредитбанк',
#  'юнипро',
#  'яндекс',
#  'ятэк'}

# %%
for report in tqdm(os.listdir(REPORTS_TXT_1000)):
    if not report.endswith('.txt'):
        continue
    report_filename = f'{REPORTS_TXT_1000}/{report}'
    with open(report_filename) as f:
        report_text = f.read()
    report_text_lst = word_tokenize(report_text)
    report_words = [report_word for report_word in report_text_lst if report_word not in lemmatized_company_names]
    new_report_filename = f'{REPORTS_TXT_1000}/{report}'
    with open(new_report_filename, 'w') as f:
        f.write(' '.join(report_words))
        
for report in tqdm(os.listdir(REPORTS_TXT_100)):
    if not report.endswith('.txt'):
        continue
    report_filename = f'{REPORTS_TXT_100}/{report}'
    with open(report_filename) as f:
        report_text = f.read()
    report_text_lst = word_tokenize(report_text)
    report_words = [report_word for report_word in report_text_lst if report_word not in lemmatized_company_names]
    new_report_filename = f'{REPORTS_TXT_100}/{report}'
    with open(new_report_filename, 'w') as f:
        f.write(' '.join(report_words))
# Out:
# 100%|███████████████████████████████████████| 1001/1001 [00:11<00:00, 89.25it/s]
# 100%|█████████████████████████████████████████| 178/178 [00:01<00:00, 93.33it/s]
